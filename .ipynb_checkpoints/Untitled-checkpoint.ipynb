# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.11.1 in c:\users\prajwalitha\anaconda3\lib\site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\prajwalitha\appdata\roaming\python\python37\site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\prajwalitha\anaconda3\lib\site-packages (from tweepy) (1.7.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\prajwalitha\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\prajwalitha\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prajwalitha\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\prajwalitha\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler('DrNvUACKRFK4uuqMNWK8fme74','n14bDTQOv6WHZDG7coxGsHNeI6sz3wbvqAxsCDRlxawBKdMEzl')
auth.set_access_token('1195378945828376577-YtteTtRc3PB4KPaVz8tcVlKBEkFY94','D2tMLjXsC4aHTnTu3yJB4tnAA8HmXPiW0wD1nVtOCRUE3')

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Had a wonderful interaction with leaders and MPs across party lines this evening.
#
# We look forward to a productive… https://t.co/E2AZIbmtpk
# झारखंड की जनता को राज्य के स्थापना दिवस की बहुत-बहुत बधाई।
#
# मेरी कामना है कि झारखंड प्रगति की नित नई ऊंचाइयों को छु… https://t.co/HO35couRby
# I would like to specially thank the people and Government of Brazil for the excellent hospitality during this year’… https://t.co/fTSTHU8XMI
# Gostaria de agradecer especialmente ao povo e ao governo do Brasil por sua excelente hospitalidade durante a Cúpula… https://t.co/24xgWaIwl2
# The BRICS Summit in Brazil has been a very productive one. We had fruitful dialogues on cementing ties in trade, in… https://t.co/CR7wZwBVLx
# It was a delight to interact with my friend, President @CyrilRamaphosa during the BRICS Summit. We discussed a wide… https://t.co/m2ktMfPST2
# I also suggested:
#
# A working group to share best practices from our respective small and medium enterprises.
#
# Stre… https://t.co/m3qnvn91CS
# At the interaction with BRICS Business Council and NDB I made the following suggestions:
#
# Charting a roadmap for In… https://t.co/aUHesJoEOI
# Addressing the Dialogue with BRICS Business Council and New Development Bank. https://t.co/P1cqBGBBfL
# Addressing the BRICS Plenary Session. https://t.co/t8ZZkfOrQW
# गणितज्ञ डॉ. वशिष्ठ नारायण सिंह जी के निधन के समाचार से अत्यंत दुख हुआ। उनके जाने से देश ने ज्ञान-विज्ञान के क्षेत्र… https://t.co/guR3aBrrZI
# Tributes to our former PM Pandit Jawaharlal Nehru on his birth anniversary.
# Addressing the BRICS Business Council. Watch. https://t.co/O4uNMHHzH0
# Held talks with President Xi Jinping. Several subjects pertaining to deepening bilateral cooperation were discussed… https://t.co/bUX1RoX5C6
# 我与习近平主席举行了会谈，讨论了深化双边合作的几个话题。
#
# 今天的讨论将为印中关系增添新的活力。 https://t.co/rQtlfFNiYJ
# Met President @jairbolsonaro on the sidelines of the BRICS Summit in Brazil. Grateful to him and the people of Braz… https://t.co/WlS4qnTFjW
# Durante nossas conversas de hoje, discutimos o aprofundamento da cooperação em áreas relacionadas à economia, conec… https://t.co/03TNf4WbRh
# Encontrei o Presidente @jairbolsonaro no contexto da Cúpula do BRICS no Brasil.  Agradecido a ele e ao povo do Bras… https://t.co/PDm4q9lzZT
# Had an excellent meeting with President Putin. During our talks, we reviewed the full range of India-Russia relatio… https://t.co/QkhEcPalqi
# Провели прекрасную встречу с президентом Путиным. В ходе наших переговоров мы рассмотрели весь спектр индийско-росс… https://t.co/6sImT6e70G

# %%
api.trends_place(1)
# Out:
# [{'trends': [{'name': 'Roger Stone',
#     'url': 'http://twitter.com/search?q=%22Roger+Stone%22',
#     'promoted_content': None,
#     'query': '%22Roger+Stone%22',
#     'tweet_volume': 218317},
#    {'name': 'Gabriel Jesus',
#     'url': 'http://twitter.com/search?q=%22Gabriel+Jesus%22',
#     'promoted_content': None,
#     'query': '%22Gabriel+Jesus%22',
#     'tweet_volume': 16830},
#    {'name': '#ImpeachingHearings',
#     'url': 'http://twitter.com/search?q=%23ImpeachingHearings',
#     'promoted_content': None,
#     'query': '%23ImpeachingHearings',
#     'tweet_volume': 95068},
#    {'name': '#BRAxARG',
#     'url': 'http://twitter.com/search?q=%23BRAxARG',
#     'promoted_content': None,
#     'query': '%23BRAxARG',
#     'tweet_volume': None},
#    {'name': 'Paquetá',
#     'url': 'http://twitter.com/search?q=Paquet%C3%A1',
#     'promoted_content': None,
#     'query': 'Paquet%C3%A1',
#     'tweet_volume': 10544},
#    {'name': '#سوبر_كلاسيكو',
#     'url': 'http://twitter.com/search?q=%23%D8%B3%D9%88%D8%A8%D8%B1_%D9%83%D9%84%D8%A7%D8%B3%D9%8A%D9%83%D9%88',
#     'promoted_content': None,
#     'query': '%23%D8%B3%D9%88%D8%A8%D8%B1_%D9%83%D9%84%D8%A7%D8%B3%D9%8A%D9%83%D9%88',
#     'tweet_volume': 12643},
#    {'name': 'Yovanovitch',
#     'url': 'http://twitter.com/search?q=Yovanovitch',
#     'promoted_content': None,
#     'query': 'Yovanovitch',
#     'tweet_volume': 691980},
#    {'name': '#FightingForWonho',
#     'url': 'http://twitter.com/search?q=%23FightingForWonho',
#     'promoted_content': None,
#     'query': '%23FightingForWonho',
#     'tweet_volume': 103324},
#    {'name': '#BestCartoonThemeSong',
#     'url': 'http://twitter.com/search?q=%23BestCartoonThemeSong',
#     'promoted_content': None,
#     'query': '%23BestCartoonThemeSong',
#     'tweet_volume': 11895},
#    {'name': 'Başörtülülere Saldırı',
#     'url': 'http://twitter.com/search?q=%22Ba%C5%9F%C3%B6rt%C3%BCl%C3%BClere+Sald%C4%B1r%C4%B1%22',
#     'promoted_content': None,
#     'query': '%22Ba%C5%9F%C3%B6rt%C3%BCl%C3%BClere+Sald%C4%B1r%C4%B1%22',
#     'tweet_volume': 14244},
#    {'name': 'Alex Sandro',
#     'url': 'http://twitter.com/search?q=%22Alex+Sandro%22',
#     'promoted_content': None,
#     'query': '%22Alex+Sandro%22',
#     'tweet_volume': None},
#    {'name': 'TevhidveAdalet Mücadelesi',
#     'url': 'http://twitter.com/search?q=%22TevhidveAdalet+M%C3%BCcadelesi%22',
#     'promoted_content': None,
#     'query': '%22TevhidveAdalet+M%C3%BCcadelesi%22',
#     'tweet_volume': None},
#    {'name': 'Brasil x Argentina',
#     'url': 'http://twitter.com/search?q=%22Brasil+x+Argentina%22',
#     'promoted_content': None,
#     'query': '%22Brasil+x+Argentina%22',
#     'tweet_volume': None},
#    {'name': 'Devlete DerinOperasyon',
#     'url': 'http://twitter.com/search?q=%22Devlete+DerinOperasyon%22',
#     'promoted_content': None,
#     'query': '%22Devlete+DerinOperasyon%22',
#     'tweet_volume': None},
#    {'name': 'Max Kellerman',
#     'url': 'http://twitter.com/search?q=%22Max+Kellerman%22',
#     'promoted_content': None,
#     'query': '%22Max+Kellerman%22',
#     'tweet_volume': None},
#    {'name': 'Witness',
#     'url': 'http://twitter.com/search?q=Witness',
#     'promoted_content': None,
#     'query': 'Witness',
#     'tweet_volume': 463349},
#    {'name': 'アナ雪',
#     'url': 'http://twitter.com/search?q=%E3%82%A2%E3%83%8A%E9%9B%AA',
#     'promoted_content': None,
#     'query': '%E3%82%A2%E3%83%8A%E9%9B%AA',
#     'tweet_volume': 139616},
#    {'name': 'Ambassador',
#     'url': 'http://twitter.com/search?q=Ambassador',
#     'promoted_content': None,
#     'query': 'Ambassador',
#     'tweet_volume': 458645},
#    {'name': 'Stefanik',
#     'url': 'http://twitter.com/search?q=Stefanik',
#     'promoted_content': None,
#     'query': 'Stefanik',
#     'tweet_volume': 22271},
#    {'name': '#RogerStoneTrial',
#     'url': 'http://twitter.com/search?q=%23RogerStoneTrial',
#     'promoted_content': None,
#     'query': '%23RogerStoneTrial',
#     'tweet_volume': None},
#    {'name': '#الارجنتين_البرازيل',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7%D8%B1%D8%AC%D9%86%D8%AA%D9%8A%D9%86_%D8%A7%D9%84%D8%A8%D8%B1%D8%A7%D8%B2%D9%8A%D9%84',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%A7%D8%B1%D8%AC%D9%86%D8%AA%D9%8A%D9%86_%D8%A7%D9%84%D8%A8%D8%B1%D8%A7%D8%B2%D9%8A%D9%84',
#     'tweet_volume': 10812},
#    {'name': '#GilmarMendesVaiCair',
#     'url': 'http://twitter.com/search?q=%23GilmarMendesVaiCair',
#     'promoted_content': None,
#     'query': '%23GilmarMendesVaiCair',
#     'tweet_volume': 213052},
#    {'name': '#ReistenDkabİhlye10Bin',
#     'url': 'http://twitter.com/search?q=%23ReistenDkab%C4%B0hlye10Bin',
#     'promoted_content': None,
#     'query': '%23ReistenDkab%C4%B0hlye10Bin',
#     'tweet_volume': None},
#    {'name': '#NICUAcademy',
#     'url': 'http://twitter.com/search?q=%23NICUAcademy',
#     'promoted_content': None,
#     'query': '%23NICUAcademy',
#     'tweet_volume': None},
#    {'name': '#yurtiçikargo',
#     'url': 'http://twitter.com/search?q=%23yurti%C3%A7ikargo',
#     'promoted_content': None,
#     'query': '%23yurti%C3%A7ikargo',
#     'tweet_volume': None},
#    {'name': '#FridayFeeling',
#     'url': 'http://twitter.com/search?q=%23FridayFeeling',
#     'promoted_content': None,
#     'query': '%23FridayFeeling',
#     'tweet_volume': 80078},
#    {'name': '#PicoEnElOjo',
#     'url': 'http://twitter.com/search?q=%23PicoEnElOjo',
#     'promoted_content': None,
#     'query': '%23PicoEnElOjo',
#     'tweet_volume': 50457},
#    {'name': '#bananamoon',
#     'url': 'http://twitter.com/search?q=%23bananamoon',
#     'promoted_content': None,
#     'query': '%23bananamoon',
#     'tweet_volume': None},
#    {'name': '#ForaTite',
#     'url': 'http://twitter.com/search?q=%23ForaTite',
#     'promoted_content': None,
#     'query': '%23ForaTite',
#     'tweet_volume': None},
#    {'name': '#MylesGarrett',
#     'url': 'http://twitter.com/search?q=%23MylesGarrett',
#     'promoted_content': None,
#     'query': '%23MylesGarrett',
#     'tweet_volume': None},
#    {'name': '#FelizViernesATodos',
#     'url': 'http://twitter.com/search?q=%23FelizViernesATodos',
#     'promoted_content': None,
#     'query': '%23FelizViernesATodos',
#     'tweet_volume': 19015},
#    {'name': '#VamosADecirQueNO',
#     'url': 'http://twitter.com/search?q=%23VamosADecirQueNO',
#     'promoted_content': None,
#     'query': '%23VamosADecirQueNO',
#     'tweet_volume': 12390},
#    {'name': '#Huuhkajat',
#     'url': 'http://twitter.com/search?q=%23Huuhkajat',
#     'promoted_content': None,
#     'query': '%23Huuhkajat',
#     'tweet_volume': None},
#    {'name': '#مبارك_هيف_الحجرف',
#     'url': 'http://twitter.com/search?q=%23%D9%85%D8%A8%D8%A7%D8%B1%D9%83_%D9%87%D9%8A%D9%81_%D8%A7%D9%84%D8%AD%D8%AC%D8%B1%D9%81',
#     'promoted_content': None,
#     'query': '%23%D9%85%D8%A8%D8%A7%D8%B1%D9%83_%D9%87%D9%8A%D9%81_%D8%A7%D9%84%D8%AD%D8%AC%D8%B1%D9%81',
#     'tweet_volume': None},
#    {'name': '#senolmadanasla',
#     'url': 'http://twitter.com/search?q=%23senolmadanasla',
#     'promoted_content': None,
#     'query': '%23senolmadanasla',
#     'tweet_volume': 43405},
#    {'name': '#TrumpBriberyCrimes',
#     'url': 'http://twitter.com/search?q=%23TrumpBriberyCrimes',
#     'promoted_content': None,
#     'query': '%23TrumpBriberyCrimes',
#     'tweet_volume': 51142},
#    {'name': '#गोडसे_मुर्दाबाद',
#     'url': 'http://twitter.com/search?q=%23%E0%A4%97%E0%A5%8B%E0%A4%A1%E0%A4%B8%E0%A5%87_%E0%A4%AE%E0%A5%81%E0%A4%B0%E0%A5%8D%E0%A4%A6%E0%A4%BE%E0%A4%AC%E0%A4%BE%E0%A4%A6',
#     'promoted_content': None,
#     'query': '%23%E0%A4%97%E0%A5%8B%E0%A4%A1%E0%A4%B8%E0%A5%87_%E0%A4%AE%E0%A5%81%E0%A4%B0%E0%A5%8D%E0%A4%A6%E0%A4%BE%E0%A4%AC%E0%A4%BE%E0%A4%A6',
#     'tweet_volume': 34847},
#    {'name': '#ResignNowTrump',
#     'url': 'http://twitter.com/search?q=%23ResignNowTrump',
#     'promoted_content': None,
#     'query': '%23ResignNowTrump',
#     'tweet_volume': None},
#    {'name': '#BlackOutBTS',
#     'url': 'http://twitter.com/search?q=%23BlackOutBTS',
#     'promoted_content': None,
#     'query': '%23BlackOutBTS',
#     'tweet_volume': None},
#    {'name': '#hangisineinanalım',
#     'url': 'http://twitter.com/search?q=%23hangisineinanal%C4%B1m',
#     'promoted_content': None,
#     'query': '%23hangisineinanal%C4%B1m',
#     'tweet_volume': None},
#    {'name': '#فتاه_المظله',
#     'url': 'http://twitter.com/search?q=%23%D9%81%D8%AA%D8%A7%D9%87_%D8%A7%D9%84%D9%85%D8%B8%D9%84%D9%87',
#     'promoted_content': None,
#     'query': '%23%D9%81%D8%AA%D8%A7%D9%87_%D8%A7%D9%84%D9%85%D8%B8%D9%84%D9%87',
#     'tweet_volume': None},
#    {'name': '#15Nov',
#     'url': 'http://twitter.com/search?q=%2315Nov',
#     'promoted_content': None,
#     'query': '%2315Nov',
#     'tweet_volume': 59853},
#    {'name': '#ÖrtümeDokunanEliKırarım',
#     'url': 'http://twitter.com/search?q=%23%C3%96rt%C3%BCmeDokunanEliK%C4%B1rar%C4%B1m',
#     'promoted_content': None,
#     'query': '%23%C3%96rt%C3%BCmeDokunanEliK%C4%B1rar%C4%B1m',
#     'tweet_volume': None},
#    {'name': '#ChildrenInNeed2019',
#     'url': 'http://twitter.com/search?q=%23ChildrenInNeed2019',
#     'promoted_content': None,
#     'query': '%23ChildrenInNeed2019',
#     'tweet_volume': 18679},
#    {'name': '#MosquesofIndia',
#     'url': 'http://twitter.com/search?q=%23MosquesofIndia',
#     'promoted_content': None,
#     'query': '%23MosquesofIndia',
#     'tweet_volume': 11661},
#    {'name': '#قبل_الحلم15',
#     'url': 'http://twitter.com/search?q=%23%D9%82%D8%A8%D9%84_%D8%A7%D9%84%D8%AD%D9%84%D9%8515',
#     'promoted_content': None,
#     'query': '%23%D9%82%D8%A8%D9%84_%D8%A7%D9%84%D8%AD%D9%84%D9%8515',
#     'tweet_volume': None},
#    {'name': '#SexyZoneデビュー8周年',
#     'url': 'http://twitter.com/search?q=%23SexyZone%E3%83%87%E3%83%93%E3%83%A5%E3%83%BC8%E5%91%A8%E5%B9%B4',
#     'promoted_content': None,
#     'query': '%23SexyZone%E3%83%87%E3%83%93%E3%83%A5%E3%83%BC8%E5%91%A8%E5%B9%B4',
#     'tweet_volume': None},
#    {'name': '#FLA124',
#     'url': 'http://twitter.com/search?q=%23FLA124',
#     'promoted_content': None,
#     'query': '%23FLA124',
#     'tweet_volume': 112396},
#    {'name': '#Guilty',
#     'url': 'http://twitter.com/search?q=%23Guilty',
#     'promoted_content': None,
#     'query': '%23Guilty',
#     'tweet_volume': None},
#    {'name': '#RHOJ',
#     'url': 'http://twitter.com/search?q=%23RHOJ',
#     'promoted_content': None,
#     'query': '%23RHOJ',
#     'tweet_volume': None}],
#   'as_of': '2019-11-15T18:06:01Z',
#   'created_at': '2019-11-15T18:00:43Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
import pandas as pd
import numpy as np
import csv

# %%
with open('trending.csv', 'w', newline='',encoding="utf-8") as csvfile:
    fieldnames = ['UserName', 'Tweet_Text','Posted','Location','Followers_count','Favorites_count','Retweet_count','source']
    csvWriter = csv.DictWriter(csvfile, fieldnames=fieldnames)
    csvWriter.writeheader()
    for tweet in tweepy.Cursor(api.search, q='#datascience',lang="en").items(100):
    #print(tweet.user.name,tweet.text,tweet.created_at,tweet.user.location,tweet.user.followers_count,tweet.user.favourites_count,tweet.retweet_count,tweet.source)
        csvWriter.writerow({'UserName':tweet.user.name,
                        'Tweet_Text':tweet.text.encode('utf-8'),
                        'Posted':tweet.created_at,
                        'Location':tweet.user.location,
                        'Followers_count':tweet.user.followers_count,
                        'Favorites_count':tweet.user.favourites_count,
                        'Retweet_count':tweet.retweet_count,
                        'source':tweet.source})

# %%
df = pd.read_csv('trending.csv')

# %%
df.shape
# Out:
# (100, 8)

# %%
df.head()
# Out:
#               UserName                                         Tweet_Text  \
# 0           Dale Jones  b'Building ML models for everyone: understandi...
# 1            AKDM bot!  b'RT @reach2ratan: Threat Actor Impersonates U...
# 2             Graciela  b'RT @Thomas_Harrer: In China, #AI defeated a ...
# 3       M. Ummer Malik  b'RT @TopCyberNews: In China, #AI defeated a t...
# 4  Cyber Security Feed  b'RT @wiwer77: Artificial intelligence and the...
#
#                 Posted                    Location  Followers_count  \
# 0  2019-11-16 17:45:04                   Leeds, UK              268
# 1  2019-11-16 17:44:32               United States             1411
# 2  2019-11-16 17:44:25        Mexicana en Alemania            15409
# 3  2019-11-16 17:44:10  Riyadh | Dubai | Islamabad              712
# 4  2019-11-16 17:44:01                    Internet             4594
#
#    Favorites_count  Retweet_count               source
# 0               17              0        Crowdfire App
# 1               14             13          akdm_DS_bot
# 2             9616              1  Twitter for Android
# 3              459              3   Twitter for iPhone
# 4                0              7  Cyber Security Feed
